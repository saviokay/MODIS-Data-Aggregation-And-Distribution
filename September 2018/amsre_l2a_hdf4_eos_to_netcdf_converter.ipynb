# %%
import os
dir_l2a='F:/data/sat_data/amsre/L2A/'
for root_l2a, dirs_l2a, files_l2a in os.walk(dir_l2a, topdown=False):
    os.chdir(root_l2a)
    for name_l2a in files_l2a:
        print(name_l2a)
        if name_l2a.endswith(".hdf"):
            filename_l2a=os.path.join(root_l2a, name_l2a)
            #print(filename_l2a)
            doscall='c:\h4tonccf_nc4.exe ' + name_l2a
            os.system(doscall)
            print(doscall)
# Out:
# AMSR_E_L2A_BrightnessTemperatures_V12_201001010026_A.nc
# AMSR_E_L2A_BrightnessTemperatures_V12_201001010115_D.nc
# AMSR_E_L2A_BrightnessTemperatures_V12_201001010205_A.nc
# AMSR_E_L2A_BrightnessTemperatures_V12_201001010254_D.nc
# AMSR_E_L2A_BrightnessTemperatures_V12_201001010344_A.nc
# AMSR_E_L2A_BrightnessTemperatures_V12_201001010433_D.hdf
# c:\h4tonccf_nc4.exe AMSR_E_L2A_BrightnessTemperatures_V12_201001010433_D.hdf
# AMSR_E_L2A_BrightnessTemperatures_V12_201001010433_D.nc
# AMSR_E_L2A_BrightnessTemperatures_V12_201001010523_A.hdf
# c:\h4tonccf_nc4.exe AMSR_E_L2A_BrightnessTemperatures_V12_201001010523_A.hdf
# AMSR_E_L2A_BrightnessTemperatures_V12_201001010612_D.hdf
# c:\h4tonccf_nc4.exe AMSR_E_L2A_BrightnessTemperatures_V12_201001010612_D.hdf
# AMSR_E_L2A_BrightnessTemperatures_V12_201001010701_A.hdf
# c:\h4tonccf_nc4.exe AMSR_E_L2A_BrightnessTemperatures_V12_201001010701_A.hdf
# AMSR_E_L2A_BrightnessTemperatures_V12_201001010751_D.hdf
# ...
